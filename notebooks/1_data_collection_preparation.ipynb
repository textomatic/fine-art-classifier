# %% [markdown]
# # Data Collection and Preparation
#
# ---
#
# # Objective of this notebook
# * Prepare the image sets before modelling phase
#
# ---
# ## 1. Importing packages & modules

# %%
# Common modules/packages
import math
import matplotlib.pyplot as plt
import numpy as np
import pathlib, os, shutil
import random
import requests
import warnings

from zipfile import ZipFile
from PIL import Image, UnidentifiedImageError

from csv import reader

warnings.filterwarnings('ignore')

# %%
# Mount Google Drive folder
from google.colab import drive
drive.mount('/content/drive')
# change current directory after mounting
PROJ_DIR = '/content/drive/MyDrive/art-classifier'
# %cd $PROJ_DIR
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/art-classifier

# %% [markdown]
# ## 2. Data Collection
# Considering that modelling requires 3 image sets ('training', 'testing', 'valid'), a decent number of images must be collected beforehand. There are three methods to download images.
#
# ### 2.1. Extract from archive file
# There is a set of images (downloads.zip) provided located in Dataset folder.

# %%
pathToDataset = pathlib.Path.cwd().joinpath('Dataset')
os.chdir(pathToDataset)

images_file = os.path.join(pathToDataset, 'downloads.zip')

# Extracting all the images to `downloads` folder
with ZipFile(images_file, 'r') as zipObj:
   zipObj.extractall(pathToDataset)

# %% [markdown]
# ### 2.2. Direct download
# The method below helps you to be more specific whether you want to focus on an art category or you already have a list of images. This method assumes that you have a list of files containing links to images. We provide with two files as an example.

# %%
###
# Download images from a list of urls
def download_listed_images(filepath):

    # Check 'downloads' folder exists
    pathToDownload = pathlib.Path.cwd().joinpath('downloads')
    if not pathToDownload.exists():
        pathToDownload.mkdir()

    # Check Art Category folder exists
    pathToDownload = pathToDownload.joinpath(filepath[:-4])
    if not pathToDownload.exists():
        pathToDownload.mkdir()
    
    # grab the list of URLs from the input file, then initialize the total number of images downloaded so far
    urls = open(filepath).read().strip().split("\n")
    urlCounter = 0

    # loop the URLs
    for url in urls:
        try:
            # try to download the image
            req = requests.get(url, timeout=60)

            # save the image to disk
            pathToDownloadedImage = pathToDownload.joinpath("{}.jpg".format(str(urlCounter).zfill(8)))
            downloaded_image = open(pathToDownloadedImage, "wb")
            downloaded_image.write(req.content)
            downloaded_image.close()

            # update the counter
            print("[INFO] downloaded: {}".format(pathToDownloadedImage))
            urlCounter += 1
            
        # handle if any exceptions are thrown during the download process
        except:
            print("[INFO] error downloading {}...skipping".format(pathToDownloadedImage))

# %% [markdown]
# Invoke the 'download_listed_images' function with a list of files containing the urls

# %%
###
# List of files
image_files = ['cubism.txt', 'surrealism.txt']
for image_file in image_files:
    download_listed_images(image_file)
# Out:
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000000.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000001.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000002.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000003.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000004.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000005.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000006.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000007.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000008.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000009.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000010.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000011.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000012.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000013.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000014.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000015.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000016.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000017.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000018.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000019.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000020.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000021.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000022.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000023.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000024.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000025.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000026.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000027.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000028.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000029.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000030.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000031.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000032.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000033.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000034.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000035.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000036.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000037.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000038.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000039.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000040.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000041.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000042.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000043.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000044.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000045.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000046.jpg
# [INFO] error downloading /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000046.jpg...skipping
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000047.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000048.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000049.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000050.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000051.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000052.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000053.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000054.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000055.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000056.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000057.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000058.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000059.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000060.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000061.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000062.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000063.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000064.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000065.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000066.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000067.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000068.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000069.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000070.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000071.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000072.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000073.jpg
# [INFO] error downloading /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000073.jpg...skipping
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000074.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000075.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000076.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000077.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000078.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000079.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000080.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000081.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000082.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000083.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000084.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000085.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000086.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000087.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000088.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000089.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000090.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000091.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000092.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000093.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000094.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000095.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000096.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000097.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000098.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000099.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000100.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000101.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000102.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000103.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000104.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000105.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000106.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000107.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000108.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000109.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000110.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000111.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000112.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000113.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000114.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000115.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000116.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000117.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000118.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000119.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000120.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000121.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000122.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000123.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000124.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000125.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000126.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000127.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000128.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000129.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000130.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000131.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000132.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000133.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000134.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000135.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000136.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000137.jpg
# [INFO] error downloading /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000137.jpg...skipping
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000138.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000139.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000140.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000141.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000142.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000143.jpg
# [INFO] error downloading /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000143.jpg...skipping
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000144.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000145.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000146.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000147.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000148.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000149.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000150.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000151.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000152.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000153.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000154.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000155.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000156.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000157.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000158.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000159.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000160.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000161.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000162.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000163.jpg
# [INFO] error downloading /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000163.jpg...skipping
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000164.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000165.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000166.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000167.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000168.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000169.jpg
# [INFO] error downloading /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000169.jpg...skipping
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000170.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000171.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000172.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000173.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000174.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000175.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000176.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000177.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000178.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000179.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000180.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000181.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000182.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000183.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000184.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000185.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000186.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000187.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000188.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000189.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000190.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000191.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000192.jpg
# [INFO] error downloading /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000192.jpg...skipping
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000193.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000194.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000195.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000196.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000197.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000198.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000199.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000200.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000201.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000202.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000203.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000204.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000205.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000206.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000207.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000208.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000209.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000210.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000211.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000212.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000213.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000214.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000215.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000216.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000217.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000218.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000219.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000220.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000221.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000222.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000223.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000224.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000225.jpg
# [INFO] error downloading /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000225.jpg...skipping
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000226.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000227.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000228.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000229.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000230.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000231.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000232.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000233.jpg
# [INFO] error downloading /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000233.jpg...skipping
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000234.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000235.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000236.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000237.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000238.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000239.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000240.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000241.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000242.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000243.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000244.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000245.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000246.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000247.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000248.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000249.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000250.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000251.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000252.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000253.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000254.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000255.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000256.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000257.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000258.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000259.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000260.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000261.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000262.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000263.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000264.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000265.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000266.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000267.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000268.jpg
# [INFO] error downloading /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000268.jpg...skipping
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000269.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000270.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000271.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000272.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000273.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000274.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000275.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000276.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000277.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000278.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000279.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000280.jpg
# [INFO] error downloading /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000280.jpg...skipping
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000281.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000282.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000283.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000284.jpg
# [INFO] error downloading /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000284.jpg...skipping
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/cubism/00000285.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000000.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000001.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000002.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000003.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000004.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000005.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000006.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000007.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000008.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000009.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000010.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000011.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000012.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000013.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000014.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000015.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000016.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000017.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000018.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000019.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000020.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000021.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000022.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000023.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000024.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000025.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000026.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000027.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000028.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000029.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000030.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000031.jpg
# [INFO] error downloading /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000031.jpg...skipping
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000032.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000033.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000034.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000035.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000036.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000037.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000038.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000039.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000040.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000041.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000042.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000043.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000044.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000045.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000046.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000047.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000048.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000049.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000050.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000051.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000052.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000053.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000054.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000055.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000056.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000057.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000058.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000059.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000060.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000061.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000062.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000063.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000064.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000065.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000066.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000067.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000068.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000069.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000070.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000071.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000072.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000073.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000074.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000075.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000076.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000077.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000078.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000079.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000080.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000081.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000082.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000083.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000084.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000085.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000086.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000087.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000088.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000089.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000090.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000091.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000092.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000093.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000094.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000095.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000096.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000097.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000098.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000099.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000100.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000101.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000102.jpg
# [INFO] error downloading /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000102.jpg...skipping
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000103.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000104.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000105.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000106.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000107.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000108.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000109.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000110.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000111.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000112.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000113.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000114.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000115.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000116.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000117.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000118.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000119.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000120.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000121.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000122.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000123.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000124.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000125.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000126.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000127.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000128.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000129.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000130.jpg
# [INFO] error downloading /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000130.jpg...skipping
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000131.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000132.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000133.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000134.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000135.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000136.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000137.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000138.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000139.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000140.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000141.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000142.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000143.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000144.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000145.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000146.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000147.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000148.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000149.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000150.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000151.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000152.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000153.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000154.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000155.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000156.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000157.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000158.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000159.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000160.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000161.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000162.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000163.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000164.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000165.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000166.jpg
# [INFO] error downloading /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000166.jpg...skipping
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000167.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000168.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000169.jpg
# [INFO] error downloading /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000169.jpg...skipping
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000170.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000171.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000172.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000173.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000174.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000175.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000176.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000177.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000178.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000179.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000180.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000181.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000182.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000183.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000184.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000185.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000186.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000187.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000188.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000189.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000190.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000191.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000192.jpg
# [INFO] downloaded: /content/drive/MyDrive/art-classifier/Dataset/downloads/surrealism/00000193.jpg

# %% [markdown]
# # 3. Data Preparation
# Now that the images are downloaded, begin to prepare the datasets.
#
# For example, the training images are all stored in a directory path that looks like this:
# ```
# dataset/train/artCategory_1/abc123.jpg
# dataset/train/artCategory_1/abc456.jpg
# dataset/train/artCategory_1/abc789.jpg
# ...
# dataset/train/artCategory_2/abc123.jpg
# dataset/train/artCategory_2/abc456.jpg
# dataset/train/artCategory_2/abc789.jpg
# ```
#
# Where, in this case, the root folder for training is `dataset/train` and the classes are the names of art types. Likewise, `dataset/valid` and `dataset/test` are for validation and testing respectively.
#
# ## 3.1. Preparation functions
#
# Before separating the images, define two utilities functions:
# * One function should return a list of files present in a specific directory
# * One function should return a sorted list of folder names present in a specific directory

# %%
# Retrieves the list of files with a directory
def getFilesInDirectory(pathToDir, extension = "*.*"):
    dir_path = pathlib.Path(pathToDir)
    file_list = list(dir_path.glob(extension))
    return file_list
    
# Retrieves the list of folders with a directory
def getFolderNamesInDirectory(pathToDir):
    dir_path = pathlib.Path(pathToDir)
    dir_list = [dir.name for dir in dir_path.iterdir() if dir.is_dir()]
    dir_list.sort()
    return dir_list

# %% [markdown]
# ## 3.2. Prepare the images
# * Set the location for `train`, `test` and `valid` folders and create the missing folders

# %%
###
# Sets the root folder for image sets
pathToDataset  = pathlib.Path.cwd()
pathToDownload = pathToDataset.joinpath('downloads')

pathToTrain = pathToDataset.joinpath('train')
if not pathToTrain.exists():
    pathToTrain.mkdir()

pathToTest = pathToDataset.joinpath('test')
if not pathToTest.exists():
    pathToTest.mkdir()

pathToValid = pathToDataset.joinpath('valid')
if not pathToValid.exists():
    pathToValid.mkdir()

###
# Sets the folder for models (where all the models will be saved)
pathToModels = pathToDataset.joinpath('..', 'models')
if not pathToModels.exists():
    pathToModels.mkdir()

# %% [markdown]
# * Count the number of art categories and list them using the function above

# %%
# list the folders required under 'dataset' folder (using a list to reduce the lines of code)
artCategories = getFolderNamesInDirectory(pathToDownload)  #collects the list of folders
print("Total no. of categories = ", len(artCategories))  #displays the number of classes (= Art categories)
print("Categories: ", artCategories)  #displays the list of classes
# Out:
# Total no. of categories =  6
# Categories:  ['cubism', 'genre', 'landscape', 'portrait', 'still-life', 'surrealism']

# %% [markdown]
# * For each art category in the downloads folder, spread the images to `test` folder (20% of them) and `valid` folder (20% of them)

# %%
# For each art category
for artCategory in artCategories:

    # Sets the source folder
    path_source = pathToDownload.joinpath(artCategory)
    
    # Sets the datasets
    image_list = getFilesInDirectory(path_source, '*.jpg') # lists all the 'jpg' images in the folder
    random.shuffle(image_list) # shuffle image list
    split_index = int(round(len(list(image_list))/5)) # Determines the splitting index: 5 = 20%
    split_images = np.split(image_list, [3*split_index, 4*split_index])# Split the files across the 3 datasets

    # Sets the target folders
    path_target_train = pathToTrain.joinpath(artCategory)
    if not path_target_train.exists():
        path_target_train.mkdir()
    for img_file in split_images[0]:
        shutil.move(img_file, path_target_train.joinpath(img_file.name))    
            
    path_target_test = pathToTest.joinpath(artCategory)
    if not path_target_test.exists():
        path_target_test.mkdir()
    for img_file in split_images[1]:
        shutil.move(img_file, path_target_test.joinpath(img_file.name))    

    path_target_valid = pathToValid.joinpath(artCategory)
    if not path_target_valid.exists():
        path_target_valid.mkdir()
    for img_file in split_images[2]:
        shutil.move(img_file, path_target_valid.joinpath(img_file.name))

# %% [markdown]
# ## 4. Check the folder content
#
# Folder now has the following structure:
#  * root >  dataset >  downloads
#  * root >  dataset >  test
#  * root >  dataset >  train
#  * root >  dataset >  valid
#
# Some of the downloaded image files might be corrupted or are not images. Define a function to remove these files.

# %%
def cleanImages(location):
    artCategories = getFolderNamesInDirectory(location)

    # For each art category
    for artCategory in artCategories:

        # Sets the source folder
        path_source = location.joinpath(artCategory)

        # Sets the datasets
        files = getFilesInDirectory(path_source, '*.jpg')    # lists all the 'jpg' images in the folder

        for file in files:
            try:
                img = Image.open(file)
            except IOError:
                print("IOError:")
                print(file)
                os.remove(file)
            except UnidentifiedImageError:
                print("UnidentifiedImageError:")
                print(file)
                os.remove(file)

pathToTrain = pathlib.Path.cwd().joinpath('..', 'Dataset', 'train')
cleanImages(pathToTrain)

pathToValid = pathlib.Path.cwd().joinpath('..', 'Dataset', 'valid')
cleanImages(pathToValid)

pathToTest = pathlib.Path.cwd().joinpath('..', 'Dataset', 'test')
cleanImages(pathToTest)
# Out:
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/valid/cubism/00000066.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/valid/cubism/00000068.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/valid/cubism/00000130.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/valid/cubism/00000155.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/valid/cubism/00000227.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/valid/cubism/00000230.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/valid/cubism/00000245.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/valid/surrealism/00000014.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/valid/surrealism/00000053.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/valid/surrealism/00000070.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/valid/surrealism/00000093.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/valid/surrealism/00000098.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/valid/surrealism/00000108.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/test/cubism/00000023.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/test/cubism/00000042.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/test/cubism/00000043.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/test/cubism/00000090.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/test/cubism/00000093.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/test/cubism/00000131.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/test/cubism/00000172.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/test/cubism/00000196.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/test/cubism/00000233.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/test/cubism/00000263.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/test/surrealism/00000062.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/test/surrealism/00000114.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/test/surrealism/00000123.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/test/surrealism/00000145.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/test/surrealism/00000152.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/test/surrealism/00000167.jpg
# IOError:
# /content/drive/MyDrive/art-classifier/Dataset/../Dataset/test/surrealism/00000172.jpg
